# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavoandrade811-beep/estruturaequalidadeatividade7/blob/Questao1/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

dados = {
    "Data": [
        "01/09/2026", "02/09/2026", "03/09/2026",
        "04/09/2026", "05/09/2026", "06/09/2026"
    ],
    "Produto": [
        "Notebook", "Mouse", "Teclado",
        "Monitor", "Cadeira", "Notebook"
    ],
    "Categoria": [
        "Informática", "Informática", "Informática",
        "Informática", "Móveis", "Informática"
    ],
    "Cidade": [
        "Goiânia", "Goiânia", "Anápolis",
        "Goiânia", "Anápolis", "Aparecida"
    ],
    "Quantidade": [2, 5, 3, 2, 2, 1],
    "Preço": [3500, 80, 150, 900, 700, 3500],
    "Vendedor": [
        "Ana", "João", "Ana",
        "Carlos", "João", "Carlos"
    ]
}

df = pd.DataFrame(dados)

print(df)
# Out:
#          Data   Produto    Categoria     Cidade  Quantidade  Preço Vendedor
# 0  01/09/2026  Notebook  Informática    Goiânia           2   3500      Ana
# 1  02/09/2026     Mouse  Informática    Goiânia           5     80     João
# 2  03/09/2026   Teclado  Informática   Anápolis           3    150      Ana
# 3  04/09/2026   Monitor  Informática    Goiânia           2    900   Carlos
# 4  05/09/2026   Cadeira       Móveis   Anápolis           2    700     João
# 5  06/09/2026  Notebook  Informática  Aparecida           1   3500   Carlos

# %% [markdown]
# Questão 0
# Pegam os dados que estão no Python, transformam em uma tabela e salvam essa tabela
# em um arquivo CSV.
#
# Questão 1
# Qual foi a quantidade total de produtos vendidos?
#
# Questão 2
# Qual foi o faturamento total?
# Dica: criar uma coluna chamada Faturamento.
#
# Figura 1 - Base de Vendas
#
# Questão 3
# Qual produto teve a maior quantidade de unidades vendidas?
# Questão 4
# Qual cidade teve o maior faturamento?
# Questão 5
# Qual vendedor realizou mais vendas em quantidade de produtos?
# Questão 6
# Qual foi o produto mais caro vendido?
# Questão 7
# Qual categoria teve o maior faturamento?
# Questão 8
# Mostre apenas as vendas realizadas em Goiânia.
# Questão 9
# Mostre somente as vendas de Notebook.
# Questão 10
# Ordene os dados do maior para o menor faturamento.

# %% [markdown]
# ## Questão 1: Quantidade total de produtos vendidos

# %%
total_quantidade_vendida = df['Quantidade'].sum()
print(f"A quantidade total de produtos vendidos foi: {total_quantidade_vendida}")
# Out:
# A quantidade total de produtos vendidos foi: 15
